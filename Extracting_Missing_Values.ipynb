# %% [markdown]
# <a href="https://colab.research.google.com/github/swapnilchavan0707/SwapMLDev/blob/main/Extracting_Missing_Values.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# Reading Our Dataset

data = pd.read_csv('/content/diabetes.csv')

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Total Rows & Columns

data.shape
# Out:
# (768, 9)

# %%
# Basic Statistics

data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# **Replacing 0 with Nan**

# %%
# All columns

columns = list(data)
columns
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Outcome']

# %%
# Checking Null Values

data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# Calculating Total Zeros in Glucose, BloodPressure, SkinThickness, Insulin and BMI

(data[columns[1:6]] == 0).sum()
# Out:
# Glucose            5
# BloodPressure     35
# SkinThickness    227
# Insulin          374
# BMI               11
# dtype: int64

# %%
# Replace Statement

data[columns[1:6]] = data[columns[1:6]].replace(0,np.nan)

# %%
# Again Checking Null Values

data.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %% [markdown]
# **Drop Empty Rows**

# %%
# Before Drop Statement

data.shape
# Out:
# (768, 9)

# %%
# Drop Statment

data.dropna(inplace = True)

# %%
# After Drop Statement

data.shape
# Out:
# (392, 9)

# %%
768/2
# Out:
# 384.0

# %%
768-392
# Out:
# 376

# %% [markdown]
# #Dealing With Missing Values
#
# Imputation Techniques
#
# *   Mean , Median , Mode

# %%
data = pd.read_csv('/content/CompanyProfit.csv')
data2 = pd.read_csv('/content/CompanyProfit_new.csv')
data3 = pd.read_csv('/content/CompanySuccess.csv')

# %%
data.head(10)
# Out:
#    Year  Profit ($)
# 0  1920       522.0
# 1  1921      1573.0
# 2  1922      2027.0
# 3  1923      1069.0
# 4  1924      1051.0
# 5  1925       872.0
# 6  1926         NaN
# 7  1927       450.0
# 8  1928      1710.0
# 9  1929      1537.0

# %%
# Checking Empty Values

data.isnull().sum()
# Out:
# Year           0
# Profit ($)    10
# dtype: int64

# %%
import seaborn as sns

# %%
# Distribution Plot to identify Which Technique to use

sns.distplot(data['Profit ($)'])
# Out:
# /tmp/ipython-input-24-1284210037.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Profit ($)'])
# <Axes: xlabel='Profit ($)', ylabel='Density'>

# %%
# # Fillna Method Using Mean

col = data['Profit ($)']

col = col.fillna(col.mean(), inplace = True)

# %%
# After Fillna Method

data.isnull().sum()
# Out:
# Year          0
# Profit ($)    0
# dtype: int64

# %%
data.head(20)
# Out:
#     Year   Profit ($)
# 0   1920   522.000000
# 1   1921  1573.000000
# 2   1922  2027.000000
# 3   1923  1069.000000
# 4   1924  1051.000000
# 5   1925   872.000000
# 6   1926  1073.505495
# 7   1927   450.000000
# 8   1928  1710.000000
# 9   1929  1537.000000
# 10  1930   249.000000
# 11  1931   855.000000
# 12  1932   870.000000
# 13  1933   453.000000
# 14  1934   655.000000
# 15  1935   914.000000
# 16  1936  1703.000000
# 17  1937  1073.505495
# 18  1938   571.000000
# 19  1939  1324.000000

# %% [markdown]
# **Median Technique**

# %%
data2.isnull().sum()
# Out:
# Year           0
# Profit ($)    15
# dtype: int64

# %%
# Distribution Plot to identify Which Technique to use

sns.distplot(data2['Profit ($)'])
# Out:
# /tmp/ipython-input-29-436855274.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data2['Profit ($)'])
# <Axes: xlabel='Profit ($)', ylabel='Density'>

# %%
# # Fillna Method Using Median

col = data2['Profit ($)']

col = col.fillna(col.median(), inplace = True)

# %%
# After Fillna Method

data2.isnull().sum()
# Out:
# Year          0
# Profit ($)    0
# dtype: int64

# %% [markdown]
# **Mode Techinque**

# %%
data3.head(20)
# Out:
#     Year   Profit ($) Success
# 0   1920   522.000000     Yes
# 1   1921  1573.000000     NaN
# 2   1922  2027.000000     Yes
# 3   1923  1069.000000      No
# 4   1924  1051.000000     Yes
# 5   1925   872.000000      No
# 6   1926  1073.505495      No
# 7   1927   450.000000     Yes
# 8   1928  1710.000000     Yes
# 9   1929  1537.000000     Yes
# 10  1930   249.000000     Yes
# 11  1931   855.000000      No
# 12  1932   870.000000      No
# 13  1933   453.000000     Yes
# 14  1934   655.000000     Yes
# 15  1935   914.000000      No
# 16  1936  1703.000000     Yes
# 17  1937  1073.505495      No
# 18  1938   571.000000     Yes
# 19  1939  1324.000000     Yes

# %%
data3.isnull().sum()
# Out:
# Year           0
# Profit ($)     0
# Success       10
# dtype: int64

# %%
# # Fillna Method Using Mean, Median

# col = data3['Success']

 # col = col.fillna(col.mean(), inplace = True)

# %%
# # Fillna Method Using Mode

col = data3['Success']

col = col.fillna(col.mode()[0], inplace = True)

# %%
data3.isnull().sum()
# Out:
# Year          0
# Profit ($)    0
# Success       0
# dtype: int64
